# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Pandas : Pandas is a Python library used for data manipulation and analysis.
#
# Numpy : NumPy is a Python library used for working with arrays.
#
# Matplotlib : Matplotlib is the library for data visualization in python.
#
# Seaborn : Seaborn is a library that provides interface for statistical plotting in Python.

# %%
df=pd.read_csv("Shark Tank India Season 1.csv")
df
# Out:
#      episode_number  startup_number           brand_name  \
# 0                 1               1  BluePine Industries
# 1                 1               2        Booz scooters
# 2                 1               3  Heart up my Sleeves
# 3                 2               4           Tagz Foods
# 4                 2               5       Head and Heart
# ..              ...             ...                  ...
# 116              35             117         Elcare India
# 117              36             118             Sneakare
# 118              36             119         French Crown
# 119              36             120       Store My Goods
# 120              36             121             Devnagri
#
#                                        description  deal_offered  \
# 0                                     Frozen Momos           1.0
# 1    Renting e-bike for mobility in private spaces           1.0
# 2                               Detachable Sleeves           1.0
# ...

# %% [markdown]
# df stands for Data frame. Data frame is a two-dimensional data structure. df is a variable in which the data is stored from the csv files.
#
# pd=df.read_csv: It is used to read data from csv files

# %%
df.head() #head() : It is used to read first five lines of dataset
# Out:
#    episode_number  startup_number           brand_name  \
# 0               1               1  BluePine Industries
# 1               1               2        Booz scooters
# 2               1               3  Heart up my Sleeves
# 3               2               4           Tagz Foods
# 4               2               5       Head and Heart
#
#                                      description  deal_offered  \
# 0                                   Frozen Momos           1.0
# 1  Renting e-bike for mobility in private spaces           1.0
# 2                             Detachable Sleeves           1.0
# 3                           Healthy Potato Chips           1.0
# 4                       Brain Development Course           0.0
#
#    startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 0                      50.0                     5.0                1000.00
# 1                      40.0                    15.0                 266.67
# ...

# %%
df.tail() #tail() : It is used to read last five line of dataset.
# Out:
#      episode_number  startup_number      brand_name  \
# 116              35             117    Elcare India
# 117              36             118        Sneakare
# 118              36             119    French Crown
# 119              36             120  Store My Goods
# 120              36             121        Devnagri
#
#                          description  deal_offered  startup_ask_amount_lakhs  \
# 116             Carenting for Elders           0.0                     100.0
# 117  Shoe care and storage solutions           1.0                      20.0
# 118                Clothing Industry           0.0                     150.0
# 119                Storage solutions           1.0                     100.0
# 120             Translation platform           0.0                     100.0
#
#      startup_ask_percentage  startup_ask_valuation  deal_amount_lakhs  \
# 116                    2.50                 4000.0                0.0
# ...

# %%
df.sample(5) #sample(5) : It is used for random selection of a specified number of items from a sequnce.
# Out:
#      episode_number  startup_number            brand_name  \
# 17                6              18               Hecolll
# 117              36             118              Sneakare
# 103              32             104       Experential Etc
# 93               29              94            PlayBox TV
# 41               14              42  Good Good Piggy Bank
#
#                                    description  deal_offered  \
# 17                  Pollution Resistant Fabric           0.0
# 117            Shoe care and storage solutions           1.0
# 103  Technology layered Advertisement Services           0.0
# 93                          Streaming Platform           0.0
# 41                          Digital Piggy Bank           0.0
#
#      startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 17                      100.0                     1.0               10000.00
# 117                      20.0                     5.0                 400.00
# ...

# %%
df.dtypes #dtypes : It is used to get the datatype of the specified columns from the given datasets.
# Out:
# episode_number                int64
# startup_number                int64
# brand_name                   object
# description                  object
# deal_offered                float64
# startup_ask_amount_lakhs    float64
# startup_ask_percentage      float64
# startup_ask_valuation       float64
# deal_amount_lakhs           float64
# deal_equity                 float64
# deal_valuation              float64
# aman_invested               float64
# anupam_invested               int64
# ashneer_invested              int64
# ghazal_invested               int64
# namita_invested               int64
# peyush_invested               int64
# vineeta_invested            float64
# sharks_offering               int64
# amount_per_shark            float64
# equity_per_shark            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   episode_number            121 non-null    int64
#  1   startup_number            121 non-null    int64
#  2   brand_name                121 non-null    object
#  3   description               121 non-null    object
#  4   deal_offered              116 non-null    float64
#  5   startup_ask_amount_lakhs  121 non-null    float64
#  6   startup_ask_percentage    121 non-null    float64
#  7   startup_ask_valuation     121 non-null    float64
#  8   deal_amount_lakhs         121 non-null    float64
#  9   deal_equity               121 non-null    float64
#  10  deal_valuation            121 non-null    float64
#  11  aman_invested             105 non-null    float64
#  12  anupam_invested           121 non-null    int64
# ...

# %% [markdown]
# info() : It is used to get the Information of each and every columns of dataset. It will also provide the number of non empty cells in dataset

# %%
df.count() #count() : It is used to count the non-empty cells in every column.
# Out:
# episode_number              121
# startup_number              121
# brand_name                  121
# description                 121
# deal_offered                116
# startup_ask_amount_lakhs    121
# startup_ask_percentage      121
# startup_ask_valuation       121
# deal_amount_lakhs           121
# deal_equity                 121
# deal_valuation              121
# aman_invested               105
# anupam_invested             121
# ashneer_invested            121
# ghazal_invested             121
# namita_invested             121
# peyush_invested             121
# vineeta_invested            108
# sharks_offering             121
# amount_per_shark            121
# equity_per_shark            121
# dtype: int64

# %%
df.shape
# Out:
# (121, 21)

# %% [markdown]
# df.shape : It is used to determine the dimensions or DataFrame.
#
# Columns : 21
# Rows : 121

# %%
df.columns
# Out:
# Index(['episode_number', 'startup_number', 'brand_name', 'description',
#        'deal_offered', 'startup_ask_amount_lakhs', 'startup_ask_percentage',
#        'startup_ask_valuation', 'deal_amount_lakhs', 'deal_equity',
#        'deal_valuation', 'aman_invested', 'anupam_invested',
#        'ashneer_invested', 'ghazal_invested', 'namita_invested',
#        'peyush_invested', 'vineeta_invested', 'sharks_offering',
#        'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %% [markdown]
# df.columns : This function determines the column names

# %%
df['equity_per_shark'].mean()
# Out:
# 5.448595041322314

# %% [markdown]
# mean() : It is used to calculate the mean of given column data

# %%
df['equity_per_shark'].median()
# Out:
# 1.25

# %% [markdown]
# median() : It is used to calculate the median of given column data.

# %%
df['equity_per_shark'].mode()
# Out:
# 0    0.0
# Name: equity_per_shark, dtype: float64

# %% [markdown]
# mode() : It is used to calculate the mode of given column data.

# %%
df['equity_per_shark'].std()
# Out:
# 10.651782973271173

# %% [markdown]
# std() : It is used to find the Standard Deviation of the given column data.

# %%
df.describe()

# %% [markdown]
# describe() : It is used to describe the dataset into the count, mean, std, min, 25%, 50%(median), 75%, max.

# %%
df["deal_offered"].value_counts()
# Out:
# 1.0    68
# 0.0    48
# Name: deal_offered, dtype: int64

# %% [markdown]
# value_counts() --> It will count the no. of times the specfic column name present in the dataset

# %%
df.sort_values(["deal_offered"])
# Out:
#      episode_number  startup_number        brand_name  \
# 120              36             121          Devnagri
# 98               31              99        Scrapshala
# 97               30              98          Scholify
# 34               12              35          SweeDesi
# 68               22              69    Poo de Cologne
# ..              ...             ...               ...
# 10                4              11      JhaJi Achaar
# 69               22              70   Moonshine Meads
# 74               23              75       Modern Myth
# 89               28              90      Kunafa World
# 96               30              97  Shades of Spring
#
#                            description  deal_offered  \
# 120               Translation platform           0.0
# 98   Handmade Reusable Scrap Materials           0.0
# 97                Scholarship Platform           0.0
# 34                       Indian Sweets           0.0
# ...

# %% [markdown]
# sort_values() : It will sort the values and provides us the data in a sorted manner

# %%
print(df.isnull().sum())
# Out:
# episode_number               0
# startup_number               0
# brand_name                   0
# description                  0
# deal_offered                 5
# startup_ask_amount_lakhs     0
# startup_ask_percentage       0
# startup_ask_valuation        0
# deal_amount_lakhs            0
# deal_equity                  0
# deal_valuation               0
# aman_invested               16
# anupam_invested              0
# ashneer_invested             0
# ghazal_invested              0
# namita_invested              0
# peyush_invested              0
# vineeta_invested            13
# sharks_offering              0
# amount_per_shark             0
# equity_per_shark             0
# dtype: int64

# %% [markdown]
# isnull() : It will Return the number of the empty cells in the row.

# %%
df.drop(["vineeta_invested","startup_ask_percentage","peyush_invested"],axis=1,inplace=True)

# %% [markdown]
# drop() : It is used to delete the specified columns

# %%
df.head()
# Out:
#    episode_number  startup_number           brand_name  \
# 0               1               1  BluePine Industries
# 1               1               2        Booz scooters
# 2               1               3  Heart up my Sleeves
# 3               2               4           Tagz Foods
# 4               2               5       Head and Heart
#
#                                      description  deal_offered  \
# 0                                   Frozen Momos           1.0
# 1  Renting e-bike for mobility in private spaces           1.0
# 2                             Detachable Sleeves           1.0
# 3                           Healthy Potato Chips           1.0
# 4                       Brain Development Course           0.0
#
#    startup_ask_amount_lakhs  startup_ask_valuation  deal_amount_lakhs  \
# 0                      50.0                1000.00               75.0
# 1                      40.0                 266.67               40.0
# ...

# %% [markdown]
# After drop() function checking the dataset

# %%
df.dropna(inplace=True)

# %% [markdown]
# dropna() --> It is used to delete rows which has very less null values and bring the data in the equal manner.

# %%
df.isnull().sum()
# Out:
# episode_number              0
# startup_number              0
# brand_name                  0
# description                 0
# deal_offered                0
# startup_ask_amount_lakhs    0
# startup_ask_valuation       0
# deal_amount_lakhs           0
# deal_equity                 0
# deal_valuation              0
# aman_invested               0
# anupam_invested             0
# ashneer_invested            0
# ghazal_invested             0
# namita_invested             0
# sharks_offering             0
# amount_per_shark            0
# equity_per_shark            0
# dtype: int64

# %% [markdown]
# No null cell present in the rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 120
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   episode_number            100 non-null    int64
#  1   startup_number            100 non-null    int64
#  2   brand_name                100 non-null    object
#  3   description               100 non-null    object
#  4   deal_offered              100 non-null    float64
#  5   startup_ask_amount_lakhs  100 non-null    float64
#  6   startup_ask_valuation     100 non-null    float64
#  7   deal_amount_lakhs         100 non-null    float64
#  8   deal_equity               100 non-null    float64
#  9   deal_valuation            100 non-null    float64
#  10  aman_invested             100 non-null    float64
#  11  anupam_invested           100 non-null    int64
#  12  ashneer_invested          100 non-null    int64
# ...

# %% [markdown]
# info() : It gives the summary of the dataset.

# %% [markdown]
# OUTLIER

# %% [markdown]
# Outlier : Outlier is an observation that appears far away and diverges from an overall pattern in a sample.An outlier is a data point that differs significantly from other observations. It is a Univariate analysis because we our analizing single variable.

# %%
sns.boxplot(x=df['episode_number'])
# Out:
# <Axes: xlabel='episode_number'>

# %% [markdown]
# There are no outliers present in the episode_number column

# %%
sns.boxplot(x=df['deal_amount_lakhs'])
# Out:
# <Axes: xlabel='deal_amount_lakhs'>

# %% [markdown]
# There is outlier present in the deal_amount_lakhs column.

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# episode_number                18.25
# startup_number                61.50
# deal_offered                   1.00
# startup_ask_amount_lakhs      31.25
# startup_ask_valuation       2395.83
# deal_amount_lakhs             51.50
# deal_equity                   15.00
# deal_valuation               525.00
# aman_invested                  1.00
# anupam_invested                0.00
# ashneer_invested               0.00
# ghazal_invested                0.00
# namita_invested                0.00
# sharks_offering                2.00
# amount_per_shark              25.00
# equity_per_shark               5.50
# dtype: float64
# <ipython-input-25-d7397e803310>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# ...

# %% [markdown]
# This Calculates Interquartile Range (IQR) for each column in 25 % and 75 % and then it will substract to get the 50% of Interquartile Range (IQR)
#
#
# 1.   Q1 defines 0.25
# 2.   Q2 defines IQR
# 3.   Q3 defines 0.75

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# <ipython-input-26-f4e1682787c4>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# (34, 18)

# %% [markdown]
# (df < (Q1 - 1.5 * IQR)) : Checks for the lesser values in lower bound.
# (df > (Q3 + 1.5 * IQR)) : Checks for the greater value in upper bound.

# %% [markdown]
# EDA (Exploratory Data Analysis)

# %% [markdown]
#  Exploratory Data Analysis (EDA) is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods.

# %%
plt.scatter(df['episode_number'],df['startup_number'])

# %% [markdown]
# **SCATTER PLOT**
#
# It is Bivarent analysis because the 2 variables that is x and y are used.
# It represents data points as individual dots on a two-dimensional plane, with one variable on the x-axis and the other variable on the y-axis. Each
# dot represents an observation or data point

# %%
pie=df['startup_ask_amount_lakhs'].value_counts()
pie
# Out:
# 50.0     13
# 100.0     4
# 75.0      3
# 40.0      2
# 35.0      2
# 30.0      2
# 60.0      2
# 10.0      1
# 45.0      1
# 15.0      1
# 120.0     1
# 20.0      1
# 80.0      1
# Name: startup_ask_amount_lakhs, dtype: int64

# %%
pie.plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='startup_ask_amount_lakhs'>

# %%
df["deal_equity"].value_counts().plot(kind="pie",autopct="%.4f%%")
# Out:
# <Axes: ylabel='deal_equity'>

# %% [markdown]
# **Pie Chart**
#
# It is univarient analysis , as single variable is used.
# In this startup_ask_amount_lakhs and deal_equality can show the region in the pie format.
# It is called a "pie chart" because the chart resembles a pie that is divided into slices, with each slice representing a particular category or data
# point. The size of each slice corresponds to the proportion or percentage of the whole that each category represents.

# %%
sns.catplot(x ='startup_ask_amount_lakhs', hue ='deal_valuation',kind ='count', data = df)

# %% [markdown]
# **Count Plot**
#
# In the Countplots height of each bar represents the number of occurrences of each category in the dataset. Countplots are particularly useful
# for visualizing the frequency of different categories and identifying the most common or least common categories in the data.
# In this the number of deal_valuation has been shown

# %%
sns.displot(df['startup_ask_valuation'],kde=True)

# %% [markdown]
# **Displot**
#
# Displot is used to create a histogram to visualize the distribution of a numerical variable.
# It is used to create a KDE plot to visualize the estimated probability density function of a numerical variable. KDE plots show the smoothed
# continuous representation of the data distribution.

# %%
df.describe()
# Out:
#        episode_number  startup_number  deal_offered  startup_ask_amount_lakhs  \
# count       34.000000       34.000000     34.000000                 34.000000
# mean        22.294118       71.294118      0.058824                 55.735294
# std          9.731328       32.789992      0.238833                 25.794419
# min          2.000000        5.000000      0.000000                 10.000000
# 25%         17.250000       52.750000      0.000000                 41.250000
# 50%         23.500000       76.000000      0.000000                 50.000000
# 75%         30.750000       98.750000      0.000000                 71.250000
# max         35.000000      117.000000      1.000000                120.000000
#
#        startup_ask_valuation  deal_amount_lakhs  deal_equity  deal_valuation  \
# count              34.000000          34.000000    34.000000       34.000000
# mean             1273.529412           2.941176     0.588235       29.411765
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-42-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# **HEATMAP**
#
# A heatmap is a 2-dimensional data visualization technique that represents the magnitude of individual values within a dataset as a color. The variation in color may be by hue or intensity.

# %%
sns.countplot(data=df,x="episode_number")
# Out:
# <Axes: xlabel='episode_number', ylabel='count'>

# %%
df["episode_number"].hist()
# Out:
# <Axes: >

# %% [markdown]
#  The hist () function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %% [markdown]
# **DATA PREPROCESSING**

# %%
x=df.iloc[:,0:4]
x
# Out:
#      episode_number  startup_number                 brand_name  \
# 4                 2               5             Head and Heart
# 13                5              14               Hungry Heads
# 14                5              15         Shrawani Engineers
# 20                7              21              La Kheer Deli
# 25                9              26                      Ariro
# 26                9              27            Kabira Handmade
# 34               12              35                   SweeDesi
# 41               14              42       Good Good Piggy Bank
# 51               17              52                     Outbox
# 54               18              55          India Hemp and Co
# 56               18              57                  Anthyesti
# 57               19              58                      Ethik
# 60               19              61                 Magic lock
# 62               20              63                   Bakarmax
# ...

# %% [markdown]
# In x axis we are including all the columns except the targeted row which will be the y axis

# %%
y=df.iloc[:,4]
y
# Out:
# 4      0.0
# 13     0.0
# 14     0.0
# 20     0.0
# 25     1.0
# 26     0.0
# 34     0.0
# 41     0.0
# 51     0.0
# 54     0.0
# 56     0.0
# 57     0.0
# 60     0.0
# 62     0.0
# 70     0.0
# 71     1.0
# 73     0.0
# 77     0.0
# 82     0.0
# 84     0.0
# 86     0.0
# 92     0.0
# 93     0.0
# 94     0.0
# 97     0.0
# 98     0.0
# 99     0.0
# 101    0.0
# 102    0.0
# 105    0.0
# 107    0.0
# 111    0.0
# 115    0.0
# 116    0.0
# Name: deal_offered, dtype: float64

# %% [markdown]
# In y axis we r including the targeted row only.

# %% [markdown]
# **ENCODING**

# %% [markdown]
# Encoding is process in which the object datatype of column is converted in integer for the Machine Learning Process.

# %%
from sklearn.preprocessing import OrdinalEncoder #OrdinalEncoder : It is usedfor encoding categorical features into ordinal integers

# %%
oe=OrdinalEncoder()
x[["brand_name","description"]]=oe.fit_transform(x[["brand_name","description"]])
x
# Out:
#      episode_number  startup_number  brand_name  description
# 4                 2               5        10.0          4.0
# 13                5              14        11.0         24.0
# 14                5              15        27.0          3.0
# 20                7              21        15.0         16.0
# 25                9              26         2.0         33.0
# 26                9              27        14.0         12.0
# 34               12              35        29.0         15.0
# 41               14              42         8.0          8.0
# 51               17              52        21.0         22.0
# 54               18              55        12.0         13.0
# 56               18              57         1.0         10.0
# 57               19              58         6.0         18.0
# 60               19              61        16.0         17.0
# 62               20              63         4.0          7.0
# ...

# %% [markdown]
# Fit : It is used to perform calculations on data.
#
# Transform : It is used to apply that calculation.

# %% [markdown]
# **MODEL**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# train_test_split : It is used to split a dataset into two (or more) subsets

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# x and y axis is splitted into xtrain , xtest , ytrain ,ytest
# where xtrain and xtest will give the output model then the ytrain is provided to the model which gives the predicted value of y predy
# which is further compared with the ytest to be accurate.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# LogisticRegression : It is used to perform logistic regression
#
# classification_report : It provides a comprehensive report with metrics such as precision, recall, F1-score, and support for both classes
# (positive and negative). It helps you understand the performance of the model for each class and overall accuracy.
#
# confusion_matrix : It provides a matrix that compares the predicted class labels against the actual class labels. It helps to visualize the
# number of true positives, false positives, true negatives, and false negatives, which is useful for understanding the model's performance and
# identifying potential areas for improvement.

# %%
from sklearn.linear_model import LinearRegression #step1 - import the model

# %%
linreg = LinearRegression() ##step2 - initalize the model

# %%
linreg.fit(xtrain, ytrain) #step3 - train the model - m & c
# Out:
# LinearRegression()

# %%
ypred = linreg.predict(xtest) #step4 - make prediction

# %%
from sklearn.metrics import r2_score
print(f"Accuracy : {r2_score(ytest, ypred)}")
# Out:
# Accuracy : 0.0

# %% [markdown]
# Accuracy : It is used to see how much accurate the data it is providing by comparing the ypred and ytest

# %%
linreg.intercept_
# linreg.intercept_ : It provides the value of the intercept.
# Out:
# 0.03367791391049265

# %%
linreg.coef_
# linreg.coef_ :  It represents the coefficients associated with each feature in the linear regression equation.
# Out:
# array([ 0.13294977, -0.0404654 , -0.00568438,  0.0030287 ])

# %%
from sklearn.linear_model import LinearRegression #object of the linear regression class
model=LinearRegression() #training of the model
model.fit(x,y) #testing of the model
ypred=model.predict(x) #ypred stores the predicted value of y

# %%
ypred
# Out:
# array([ 0.04062446,  0.13517819, -0.04184152,  0.07363517,  0.24567875,
#         0.08557243,  0.10282198,  0.15034219,  0.13510807,  0.15353569,
#         0.11214323,  0.20624219,  0.04384328,  0.11052167,  0.04783235,
#         0.06201441,  0.0834849 , -0.00815644,  0.03452554,  0.02802658,
#         0.06449191,  0.08316873,  0.04337465,  0.08044601, -0.00350244,
#         0.03035491,  0.06698262,  0.06451905,  0.0253396 , -0.04739024,
#         0.03651307, -0.07204165, -0.08114475, -0.0922446 ])

# %%
from sklearn.metrics import r2_score
r2_score(y,ypred)
# Out:
# 0.10096199044479426

# %%
model.intercept_
# Out:
# 0.009442198041442022

# %%
model.coef_
# Out:
# array([ 0.12732446, -0.03892029, -0.00422835,  0.00335457])

# %%
x
# Out:
#      episode_number  startup_number  brand_name  description
# 4                 2               5        10.0          4.0
# 13                5              14        11.0         24.0
# 14                5              15        27.0          3.0
# 20                7              21        15.0         16.0
# 25                9              26         2.0         33.0
# 26                9              27        14.0         12.0
# 34               12              35        29.0         15.0
# 41               14              42         8.0          8.0
# 51               17              52        21.0         22.0
# 54               18              55        12.0         13.0
# 56               18              57         1.0         10.0
# 57               19              58         6.0         18.0
# 60               19              61        16.0         17.0
# 62               20              63         4.0          7.0
# ...

# %%
from pandas.errors import PyperclipException
brand=int(input("\n 0.Tagz Food \t 1.sweedesi \t 2.skippi Pops\t 3.Falhari \n Enter the Brand name: "))
product=int(input("\n0.Chips  1.Sweets  2.Ice Pops \t 3.Fruits\n Enter the Product Name: "))
price=0.0
amount=int(input("\nEnter the amount: "))
unknown_y=[[brand,product,price,amount]]
ynew=model.predict(unknown_y)
print("\n\nThe equity price: ",ynew)
# Out:
#  0.Tagz Food 	 1.sweedesi 	 2.skippi Pops	 3.Falhari
#  Enter the Brand name: 1
#
# 0.Chips  1.Sweets  2.Ice Pops 	 3.Fruits
#  Enter the Product Name: 3
#
# Enter the amount: 200000
#
#
# The equity price:  [670.93306268]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
